# %%
import numpy as np

import matplotlib.pylab as plt

# %%
print(np.pi)
# Out:
# 3.141592653589793

# %%
x = np.linspace(0, np.pi, 100)
plt.plot(x, np.sin(x))

# %%
x = 0.34
for i in range(1000000):
    x += np.sin(x)*np.cos(x)
